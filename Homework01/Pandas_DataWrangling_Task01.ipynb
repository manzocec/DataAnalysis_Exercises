# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
pd.options.mode.chained_assignment = None  # default='warn', Mutes warnings when copying a slice from a DataFrame.

# %% [markdown]
# # Compiling ebola data
#
# **TASK**: The `DATA_FOLDER/ebola` folder contains summarized reports of Ebola cases from three countries (Guinea, Liberia and Sierra Leone) during the recent outbreak of the disease in West Africa. For each country, there are daily reports that contain various information about the outbreak in several cities in each country. Use pandas to import these data files into a single `Dataframe`. Using this `DataFrame`, calculate for *each country*, the *daily average per month* of *new cases* and *deaths*. Make sure you handle all the different expressions for *new cases* and *deaths* that are used in the reports

# %% [markdown]
# First we load the data for each country and we collect it all in one single `DataFrame` called `ebola_alldata`.

# %%
def import_data(country):
    all_files = glob.glob('./Data/ebola/{}_data/*.csv'.format(country))
    return pd.concat([pd.read_csv(date_file) for date_file in all_files], sort=True)

# %%
guinea_data = import_data('guinea')
print(type(guinea_data))
print(len(guinea_data))
guinea_data['Country'] = ['guinea' for i in range(len(guinea_data))]
guinea_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 714
#    Beyla Boffa Conakry Coyah Dabola Dalaba        Date  \
# 0    NaN     0       5   NaN      0    NaN  2014-08-04
# 1    NaN     0       0   NaN      0    NaN  2014-08-04
# 2    NaN     0       1   NaN      0    NaN  2014-08-04
# 3    NaN     0       6   NaN      0    NaN  2014-08-04
# 4    NaN     0       9   NaN      0    NaN  2014-08-04
# 5    NaN     5       8   NaN      3    NaN  2014-08-04
# 6    NaN    18      78   NaN      1    NaN  2014-08-04
# 7    NaN    23      95   NaN      4    NaN  2014-08-04
# 8    NaN     0       0   NaN      0    NaN  2014-08-04
# 9    NaN     0       0   NaN      0    NaN  2014-08-04
# 10   NaN     0       0   NaN      0    NaN  2014-08-04
# 11   NaN     0       0   NaN      0    NaN  2014-08-04
# 12   NaN     0       2   NaN      0    NaN  2014-08-04
# 13   NaN     5       8   NaN      3    NaN  2014-08-04
# 14   NaN    11      32   NaN      1    NaN  2014-08-04
# 15   NaN    16      42   NaN      4    NaN  2014-08-04
# 16   NaN     0      21   NaN      0    NaN  2014-08-04
# 17   NaN     0      10   NaN      0    NaN  2014-08-04
# 18   NaN     0       0   NaN      0    NaN  2014-08-04
# 19   NaN     0      11   NaN      0    NaN  2014-08-04
# 20   NaN     6      20   NaN      0    NaN  2014-08-04
# 21   NaN     7      34   NaN      0    NaN  2014-08-04
# 22   NaN    10      48   NaN      1    NaN  2014-08-04
# 23   NaN     8      30   NaN      0    NaN  2014-08-04
# 24   NaN     3       4   NaN      1    NaN  2014-08-04
# 25   NaN     2       4   NaN      2    NaN  2014-08-04
# 26   NaN     0       5   NaN      0    NaN  2014-08-04
# 27   NaN     0       4   NaN      0    NaN  2014-08-04
# 28   NaN    13      57   NaN      2    NaN  2014-08-04
# 29   NaN    10      38   NaN      2    NaN  2014-08-04
# ..   ...   ...     ...   ...    ...    ...         ...
# 2    NaN   NaN       2   NaN    NaN    NaN  2014-10-01
# 3      0     0      17     0      0      0  2014-10-01
# 4      0     0      19     0      0      0  2014-10-01
# 5      0     5      10     0      3      0  2014-10-01
# 6      2    19     170    12      1      6  2014-10-01
# 7      2    24     199    12      4      6  2014-10-01
# 8      0    20     355     6      3      1  2014-10-01
# 9    NaN   NaN     NaN   NaN    NaN    NaN  2014-10-01
# 10     0     0       0     0      0      0  2014-10-01
# 11     0     5      10     0      3      0  2014-10-01
# 12     1    11      68     5      1      0  2014-10-01
# 13     0    16      78     5      4      0  2014-10-01
# 14  100%   67%     39%   42%   100%     0%  2014-10-01
# 15   NaN   NaN       2   NaN    NaN    NaN  2014-10-01
# 16     0     0      40     1      0      0  2014-10-01
# 17     0     0       0     0      0      0  2014-10-01
# 18     0     0      18     0      0      0  2014-10-01
# 19   NaN   NaN      15   NaN    NaN    NaN  2014-10-01
# 20     0     0      48     0      0      0  2014-10-01
# 21     0     0       9     0      0      0  2014-10-01
# 22     0     0     571     0      0      0  2014-10-01
# 23   NaN   NaN     NaN   NaN    NaN    NaN  2014-10-01
# 24     2   397    3319   116     69     34  2014-10-01
# 25   929     0     825    98      0     34  2014-10-01
# 26    29     0     778    98      0     20  2014-10-01
# 27     0   397    2494    17     69      0  2014-10-01
# 28     0     0       0     1      0      0  2014-10-01
# 29   NaN   NaN      16   NaN    NaN    NaN  2014-10-01
# 30   NaN   NaN       0   NaN    NaN    NaN  2014-10-01
# 31   NaN   NaN    1171   NaN    NaN    NaN  2014-10-01
#
#                                         Description Dinguiraye Dubreka  \
# 0                             New cases of suspects          0       0
# 1                            New cases of probables          0       0
# 2                            New cases of confirmed          0       0
# 3                 Total new cases registered so far          0       0
# 4                           Total cases of suspects          0       0
# 5                          Total cases of probables          1       0
# 6                          Total cases of confirmed          0       0
# 7      Cumulative (confirmed + probable + suspects)          1       0
# 8                       New deaths registered today          0       0
# 9           New deaths registered today (confirmed)          0       0
# 10          New deaths registered today (probables)          0       0
# 11           New deaths registered today (suspects)          0       0
# 12                         Total deaths of suspects          0       0
# 13                        Total deaths of probables          1       0
# 14                        Total deaths of confirmed          0       0
# 15  Total deaths (confirmed + probables + suspects)          1       0
# 16                           Total PEC center today          0       0
# 17               Total PEC center today (confirmed)          0       0
# 18               Total PEC center today (probables)          0       0
# 19                Total PEC center today (suspects)          0       0
# 20        Total of deaths in confirmed cases in CTE          0       0
# 21         Total of cured in confirmed cases in CTE          0       0
# 22                   Number of male confirmed cases          0       0
# 23                 Number of female confirmed cases          0       0
# 24                   Number of male probables cases          0       0
# 25                 Number of female probables cases          1       0
# 26                    Number of male suspects cases          0       0
# 27                  Number of female suspects cases          0       0
# 28                       Total number of male cases          0       0
# 29                     Total number of female cases          1       0
# ..                                              ...        ...     ...
# 2                            New cases of confirmed        NaN     NaN
# 3                 Total new cases registered so far          0       0
# 4                           Total cases of suspects          0       0
# 5                          Total cases of probables          1       0
# 6                          Total cases of confirmed          0      21
# 7      Cumulative (confirmed + probable + suspects)          1      21
# 8                   Total suspected non-class cases          0      20
# 9                             New deaths registered        NaN     NaN
# 10                         Total deaths of suspects          0       0
# 11                        Total deaths of probables          1       0
# 12                        Total deaths of confirmed          0       7
# 13  Total deaths (confirmed + probables + suspects)          1       7
# 14        Fatality rate for confirmed and probables       100%     33%
# 15      New cases of confirmed among health workers        NaN     NaN
# 16     Total case of confirmed among health workers          0       3
# 17       New deaths registered among health workers          0       0
# 18     Total deaths registered among health workers          0       1
# 19                         New admits to CTE so far        NaN     NaN
# 20        Total number of hospitalized cases in CTE          0       0
# 21                   Total number of exits from CTE          0       0
# 22                Total number of admissions to CTE          0       0
# 23                   New contacts registered so far        NaN     NaN
# 24        Total contacts registered from start date          0     341
# 25               Number of contacts to follow today          0      49
# 26                Number of contacts followed today          0      49
# 27      Number of contacts out of the track 21 days          0     292
# 28             Number of contacts lost to follow up          0       0
# 29                Number of samples collected today        NaN     NaN
# 30                     Number of samples under test        NaN     NaN
# 31                             Total samples tested        NaN     NaN
#
#      ...    Lola Macenta Mzerekore Nzerekore Pita Siguiri Telimele Totals  \
# 0    ...     NaN       0       NaN         0    0       0        0      5
# 1    ...     NaN       0       NaN         0    0       0        0      0
# 2    ...     NaN       0       NaN         0    0       0        0      4
# 3    ...     NaN       0       NaN         0    0       0        0      9
# 4    ...     NaN       0       NaN         0    0       0        0     11
# 5    ...     NaN      11       NaN         0    1       0        3    133
# 6    ...     NaN      28       NaN         4    1       6       23    351
# 7    ...     NaN      39       NaN         4    2       6       26    495
# 8    ...     NaN       0       NaN         0    0       0        0      2
# 9    ...     NaN       0       NaN         0    0       0        0      2
# 10   ...     NaN       0       NaN         0    0       0        0      0
# 11   ...     NaN       0       NaN         0    0       0        0      0
# 12   ...     NaN       0       NaN         0    0       0        0      2
# 13   ...     NaN      11       NaN         0    1       0        3    133
# 14   ...     NaN      18       NaN         1    1       3        7    228
# 15   ...     NaN      29       NaN         1    2       3       10    363
# 16   ...     NaN       0       NaN         0    0       2        0     31
# 17   ...     NaN       0       NaN         0    0       2        0     18
# 18   ...     NaN       0       NaN         0    0       0        0      0
# 19   ...     NaN       0       NaN         0    0       0        0     13
# 20   ...     NaN      10       NaN         0    0       2        5    138
# 21   ...     NaN       8       NaN         0    0       0        9     89
# 22   ...     NaN      14       NaN         2    0       6        6    161
# 23   ...     NaN      14       NaN         2    1       0       17    190
# 24   ...     NaN       5       NaN         0    1       0        1     52
# 25   ...     NaN       6       NaN         0    0       0        2     81
# 26   ...     NaN       0       NaN         0    0       2        0      7
# 27   ...     NaN       0       NaN         0    0       0        0      6
# 28   ...     NaN      19       NaN         2    1       8        7    220
# 29   ...     NaN      20       NaN         2    1       0       19    277
# ..   ...     ...     ...       ...       ...  ...     ...      ...    ...
# 2    ...     NaN       2       NaN       NaN  NaN     NaN      NaN      6
# 3    ...       9       5       NaN         1    0       0        0     34
# 4    ...       9       9       NaN         2    1       0        0     45
# 5    ...       0      16       NaN        17    1       0        3    177
# 6    ...       2     378       NaN        31    6       6       23    977
# 7    ...      11     403       NaN        50    8       6       26   1199
# 8    ...       4     197       NaN        16   18       9       18    974
# 9    ...     NaN      15       NaN       NaN  NaN     NaN      NaN     15
# 10   ...       0       0       NaN         0    0       0        0      0
# 11   ...       0      16       NaN        17    1       0        3    177
# 12   ...       2     230       NaN        15    2       3        7    562
# 13   ...       0     246       NaN        32    3       3       10    739
# 14   ...    100%     61%       NaN       64%  38%     50%      38%    62%
# 15   ...     NaN     NaN       NaN       NaN  NaN     NaN      NaN      2
# 16   ...       0       9       NaN         2    0       2        2     69
# 17   ...       0       0       NaN         0    0       0        0      0
# 18   ...       0       7       NaN         1    0       0        1     35
# 19   ...     NaN     NaN       NaN       NaN  NaN     NaN      NaN     25
# 20   ...     NaN      12       NaN         0    0       0        0    114
# 21   ...     NaN      15       NaN         0    0       0        0     29
# 22   ...     NaN      27       NaN         0    0      13       41   1576
# 23   ...     NaN     NaN       NaN       NaN  NaN     NaN      NaN      0
# 24   ...       0    1563       NaN       353  140     141      259  11772
# 25   ...       0    1038       NaN       126    0       0        0   2661
# 26   ...       0    1038       NaN       126    0       0        0   2595
# 27   ...       0     525       NaN       227  140     141      259   9110
# 28   ...       0       0       NaN         0    0       0        0      1
# 29   ...     NaN       0       NaN       NaN  NaN     NaN      NaN     25
# 30   ...     NaN       0       NaN       NaN  NaN     NaN      NaN      0
# 31   ...     NaN       0       NaN       NaN  NaN     NaN      NaN   2832
#
#    Yomou Country
# 0    NaN  guinea
# 1    NaN  guinea
# 2    NaN  guinea
# 3    NaN  guinea
# 4    NaN  guinea
# 5    NaN  guinea
# 6    NaN  guinea
# 7    NaN  guinea
# 8    NaN  guinea
# 9    NaN  guinea
# 10   NaN  guinea
# 11   NaN  guinea
# 12   NaN  guinea
# 13   NaN  guinea
# 14   NaN  guinea
# 15   NaN  guinea
# 16   NaN  guinea
# 17   NaN  guinea
# 18   NaN  guinea
# 19   NaN  guinea
# 20   NaN  guinea
# 21   NaN  guinea
# 22   NaN  guinea
# 23   NaN  guinea
# 24   NaN  guinea
# 25   NaN  guinea
# 26   NaN  guinea
# 27   NaN  guinea
# 28   NaN  guinea
# 29   NaN  guinea
# ..   ...     ...
# 2    NaN  guinea
# 3      0  guinea
# 4      0  guinea
# 5      0  guinea
# 6     11  guinea
# 7     11  guinea
# 8      4  guinea
# 9    NaN  guinea
# 10     0  guinea
# 11     0  guinea
# 12     5  guinea
# 13     5  guinea
# 14   45%  guinea
# 15   NaN  guinea
# 16     1  guinea
# 17     0  guinea
# 18     1  guinea
# 19   NaN  guinea
# 20     0  guinea
# 21     0  guinea
# 22     0  guinea
# 23   NaN  guinea
# 24    56  guinea
# 25     0  guinea
# 26     0  guinea
# 27    56  guinea
# 28     0  guinea
# 29   NaN  guinea
# 30   NaN  guinea
# 31   NaN  guinea
#
# [714 rows x 26 columns]

# %%
liberia_data = import_data('liberia')
print(len(liberia_data))
liberia_data['Country'] = ['liberia' for i in range(len(liberia_data))]
liberia_data.head(1)
# Out:
# 3152
#    Bomi County  Bong County       Date  Gbarpolu County  Grand Bassa  \
# 0          NaN          NaN  6/16/2014              NaN          NaN
#
#    Grand Cape Mount  Grand Gedeh  Grand Kru  Lofa County  Margibi County  \
# 0               NaN          NaN        NaN          1.0             NaN
#
#    Maryland County  Montserrado County  National  Nimba County  \
# 0              NaN                 0.0       1.0           NaN
#
#    River Gee County  RiverCess County  Sinoe County  Unnamed: 18  \
# 0               NaN               NaN           NaN          NaN
#
#               Variable  Country
# 0  Specimens collected  liberia

# %%
sl_data = import_data('sl')
print(len(sl_data))
sl_data['Country'] = ['sl' for i in range(len(sl_data))]
sl_data.head(1)
# Out:
# 3262
#    34 Military Hospital      Bo  Bo EMC Bombali  Bonthe  Hastings-F/Town  \
# 0                   NaN  654142     NaN  494139  168729              NaN
#
#   Kailahun  Kambia  Kenema  Kenema (IFRC)   ...   Pujehun Tonkolili  \
# 0   465048  341690  653013            NaN   ...    335574    434937
#
#   Unnamed: 18 Western area Western area combined  Western area rural  \
# 0         NaN          NaN                   NaN              263619
#
#    Western area urban        date    variable Country
# 0             1040888  2014-08-12  population      sl
#
# [1 rows x 28 columns]

# %% [markdown]
# We fix the columns which do not have the same name but refer to the same measure, before merging together the data from the three countries.

# %%
guinea_data = guinea_data.rename(index=str, columns={"Totals": "National"})
liberia_data = liberia_data.rename(index=str, columns={"Variable": "Description"})
sl_data = sl_data.rename(index=str, columns={"date": "Date", "variable": "Description"})

# Merge the dat afrom the three countries in one single DataFrame
ebola_alldata = guinea_data.append([liberia_data, sl_data], sort=True)

# %% [markdown]
# We define a function `label_description()` mapping the categories of interest to their corresponding nomenclature in the .csv files. This investigation must be doen country by country to find all possbile matching.

# %%
CASES_SUSPECTS = "New Cases: Suspects"
CASES_PROBABLES = "New Cases: Probables"
CASES_CONFIRMED = "New Cases: Confirmed"
DEATHS_TOTAL = "Total New Deaths"

# %%
def label_description(description):
    try:
        return {"New cases of suspects": CASES_SUSPECTS,
                "New cases of probables": CASES_PROBABLES,
                "New cases of confirmed": CASES_CONFIRMED,
                "New deaths registered": DEATHS_TOTAL,
                "New deaths registered today": DEATHS_TOTAL,
                "Newly reported deaths": DEATHS_TOTAL,
                "New Case/s (Suspected)": CASES_SUSPECTS,
                "New Case/s (Probable)": CASES_PROBABLES,
                "New case/s (confirmed)": CASES_CONFIRMED,
                "new_suspected": CASES_SUSPECTS,
                "new_probable": CASES_PROBABLES,
                "new_confirmed": CASES_CONFIRMED,
                "etc_new_deaths": DEATHS_TOTAL,
               }[description]
    except:
        return None

# %% [markdown]
# With `filter_data()` we create a `DataFrame` containing only the data of interest, then with `compute_daily_av()` we compute the daily average per month of *new cases* and *deaths* for each country.

# %%
def filter_data(data_in, label_function):
    data_out = pd.DataFrame()
    
    data_temp = data_in['Description'].apply(label_function) # DataFrame.apply(func_name) applies a fuction 
    # along an axis of the DataFrame.
    data_out['Description'] = data_temp[data_temp.notnull()]
    
    data_out['Country'] = data_in['Country'][data_temp.notnull()]
    
    data_out['National'] = data_in['National'][data_temp.notnull()]
    
    data_out['Day'] = pd.DatetimeIndex(data_in['Date'][data_temp.notnull()]).day
    data_out['Month'] = pd.DatetimeIndex(data_in['Date'][data_temp.notnull()]).month
    data_out['Year'] = pd.DatetimeIndex(data_in['Date'][data_temp.notnull()]).year
    
    data_out = data_out.set_index(['Description','Country', 'Year', 'Month', 'Day'])['National']
    data_out = data_out.unstack('Description')
    
    return data_out

# %%
#filter_data(ebola_alldata, label_description)

# %%
def compute_daily_av(data_in, label_function):
    data_out = filter_data(data_in, label_function)
    
    # Replacing NaNs with zeros and converting them into int-type
    data_out = data_out.fillna(0).astype(int)
    
    return data_out.mean(level=[0,1,2])

# %%
compute_daily_av(ebola_alldata, label_description)
# Out:
# Description         New Cases: Confirmed  New Cases: Probables  \
# Country Year Month
# guinea  2014 8                 12.400000              1.600000
#              9                 13.000000              1.187500
#              10                 6.000000              0.000000
# liberia 2014 6                  2.142857              1.142857
#              7                  1.818182              3.727273
#              8                  5.444444             19.777778
#              9                  6.166667             29.333333
#              10                 1.360000             17.760000
#              11                 2.600000              7.000000
#              12              1928.333333           1208.000000
# sl      2014 8                 18.550000              1.150000
#              9                 34.413793              0.000000
#              10                56.714286              0.857143
#              11                59.904762              0.000000
#              12                32.600000              0.000000
#
# Description         New Cases: Suspects  Total New Deaths
# Country Year Month
# guinea  2014 8                11.800000          3.400000
#              9                 5.437500          3.562500
#              10               28.000000         15.000000
# liberia 2014 6                 2.428571          2.000000
#              7                 3.000000          4.272727
#              8                12.000000         23.222222
#              9                28.333333         36.041667
#              10               26.440000         28.040000
#              11               16.866667         13.466667
#              12             2042.222222          0.000000
# sl      2014 8                 5.450000          0.000000
#              9                 6.275862          0.275862
#              10               13.357143          3.535714
#              11               15.333333          0.571429
#              12                8.400000          2.200000
