# %%
import numpy as np
import pandas as pd
import csv

# %% [markdown]
# # Loading data

# %%
data = pd.read_csv('full_data.csv');
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data.head(10)
# Out:
#    Unnamed: 0  year  month        intent  police sex   age  \
# 0           1  2012      1       Suicide       0   M  34.0
# 1           2  2012      1       Suicide       0   F  21.0
# 2           3  2012      1       Suicide       0   M  60.0
# 3           4  2012      2       Suicide       0   M  64.0
# 4           5  2012      2       Suicide       0   M  31.0
# 5           6  2012      2       Suicide       0   M  17.0
# 6           7  2012      2  Undetermined       0   M  48.0
# 7           8  2012      3       Suicide       0   M  41.0
# 8           9  2012      2    Accidental       0   M  50.0
# 9          10  2012      2       Suicide       0   M   NaN
#
#                              race  hispanic            place     education
# 0          Asian/Pacific Islander       100             Home           BA+
# 1                           White       100           Street  Some college
# 2                           White       100  Other specified           BA+
# ...

# %%
del data['Unnamed: 0']

# %%
data.tail(10)
# Out:
#         year  month    intent  police sex   age                    race  \
# 100788  2014     12  Homicide       0   M  32.0  Asian/Pacific Islander
# 100789  2014     12  Homicide       0   M  21.0                Hispanic
# 100790  2014     12   Suicide       0   M  28.0                Hispanic
# 100791  2014     12  Homicide       0   M  43.0                   Black
# 100792  2014     12  Homicide       0   M  31.0                   Black
# 100793  2014     12  Homicide       0   M  36.0                   Black
# 100794  2014     12  Homicide       0   M  19.0                   Black
# 100795  2014     12  Homicide       0   M  20.0                   Black
# 100796  2014     12  Homicide       0   M  22.0                Hispanic
# 100797  2014     10  Homicide       0   M  43.0                   Black
#
#         hispanic              place     education
# 100788       100  Other unspecified  Some college
# 100789       260             Street        HS/GED
# ...

# %%
len(data)
# Out:
# 100798

# %% [markdown]
# # Computing the ration of suicides over the number of gun deaths

# %%
data['intent'][3]
# Out:
# 'Suicide'

# %%
count_suicide = 0

for idx in range(len(data)):
    if data['intent'][idx] == 'Suicide':
        count_suicide += 1
        
print(count_suicide)
# Out:
# 63175

# %%
ratio = count_suicide/len(data)
print(ratio)
# Out:
# 0.6267485465981468
